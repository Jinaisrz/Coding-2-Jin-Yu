# %%
# this hints the game rules.
# this reminds that i understand for coding, just simple notes.

# 导入需要用的random库。import the required random library.
from random import randint

# edit the fuction of guessing number game, its parameters represent max value and max time.  
def guessNumber(maxValue,maxTime):
    # generate an integer at random
    value = randint(1,maxValue)
    for i in range(maxTime):
        prompt = "The second bit of binary:" if i==0 else "please try again"
        # I use an exception handling structure to prevent the input from not numeric.
        try:
            x = int(input(prompt))
        except:
             print("You must enter an integer between 1 and", maxValue)
        else:
            if x == value:
                # Correct!
                print("Correct")
                break
            
            elif x > value:
                print("Too big!")
            else:
                print("Too small!")
    else:
        print("Game over!")      

    
    
def asciiGuess(maxValue, maxTime):
# generate a random integer between 1 and maxValue (inclusive)
    value = randint(1,maxValue)
    for i in range(maxTime):
        prompt = "What is the ASCII value of character '1'?" if i == 0 else "Please try again."
        # use a try-except block to handle non-integer input
        try:
            guess = int(input(prompt))
        except ValueError:
            print("You must enter an integer between 1 and", maxValue)
            continue
        
        # check if the guess is correct
        if guess == ord('1'):
            print("Correct!")
            break
        elif guess < ord('1'):
            print("Too small!")
        else:
            print("Too big!")
    else:
        print("Game over. The correct answer was", ord('1'))

             
        
guessNumber(1,3) # 调用guessNumber函数
asciiGuess(127,3)
